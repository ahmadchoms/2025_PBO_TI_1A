# %%
class Komputer:
    def __init__(self, merk, processor, ram_gb):
        self.merk = merk
        self.processor = processor
        self.ram_gb = ram_gb
    
    def info_spesifikasi(self):
        print(f"Merk: {self.merk}")
        print(f"Processor: {self.processor}")
        print(f"RAM: {self.ram_gb} GB")
    
    def jalankan_aplikasi(self, nama_aplikasi):
        print(f"{self.merk} menjalankan aplikasi {nama_aplikasi}")
    
    def upgrade_ram(self, tambahan_gb, tipe_ram="DDR4"):
        self.ram_gb += tambahan_gb
        print(f"RAM {self.merk} diupgrade menjadi {self.ram_gb} GB {tipe_ram} (Tipe: {tipe_ram}).")
        print(f"Total RAM sekarang: {self.ram_gb} GB")
    
    def install_software(self, *args):
        for software in args:
            print(f"Menginstall {software} di {self.merk}")

class Laptop(Komputer):
    def __init__(self, merk, processor, ram_gb, ukuran_layar_inch, berat_kg):
        super().__init__(merk, processor, ram_gb)
        self.ukuran_layar_inch = ukuran_layar_inch
        self.berat_kg = berat_kg
    
    def info_spesifikasi(self):
        super().info_spesifikasi()
        print(f"Ukuran Layar: {self.ukuran_layar_inch} inch")
        print(f"Berat: {self.berat_kg} kg")

class Desktop(Komputer):
    def __init__(self, merk, processor, ram_gb, jenis_casing="Tower", monitor_external=True):
        super().__init__(merk, processor, ram_gb)
        self.jenis_casing = jenis_casing
        self.monitor_external = monitor_external
    
    def info_spesifikasi(self):
        super().info_spesifikasi()
        print(f"Jenis Casing: {self.jenis_casing}")
        print("Monitor External:", "Ya" if self.monitor_external else "Tidak")

def cetak_semua_spesifikasi(daftar_komputer):
    for komputer in daftar_komputer:
        komputer.info_spesifikasi()
        print()

if __name__ == "__main__":
    laptop_asus = Laptop("Asus", "Intel Core i7-12700H", 16, 15.6, 2.5)
    desktop_dell = Desktop("Dell XPS", "AMD Ryzen 9 5900X", 32)
    daftar_komputer = [laptop_asus, desktop_dell]
    cetak_semua_spesifikasi(daftar_komputer)

    print("Demonstrasi Metode Jalankan Aplikasi:")
    laptop_asus.jalankan_aplikasi("Microsoft Word")
    desktop_dell.jalankan_aplikasi("Google Chrome")
    
    print("\nDemonstrasi Overloading dengan Default Argument:")
    print("Uggrade RAM dengan nilai default untuk tipe_ram")
    laptop_asus.upgrade_ram(4)
    print("\nUggrade RAM dengan nilai eksplisit untuk tipe_ram")
    desktop_dell.upgrade_ram(8, "DDR5")
    
    print("\nDemonstrasi Overloading dengan ARGS:")
    print("Menginstall satu software:")
    laptop_asus.install_software("Adobe Photoshop")
    print("\nMenginstall beberapa software:")
    desktop_dell.install_software("Microsoft Office", "Google Drive")
# Out:
# Merk: Asus
# Processor: Intel Core i7-12700H
# RAM: 16 GB
# Ukuran Layar: 15.6 inch
# Berat: 2.5 kg
#
# Merk: Dell XPS
# Processor: AMD Ryzen 9 5900X
# RAM: 32 GB
# Jenis Casing: Tower
# Monitor External: Ya
#
# Demonstrasi Metode Jalankan Aplikasi:
# Asus menjalankan aplikasi Microsoft Word
# Dell XPS menjalankan aplikasi Google Chrome
#
# Demonstrasi Overloading dengan Default Argument:
# Uggrade RAM dengan nilai default untuk tipe_ram
# RAM Asus diupgrade menjadi 20 GB DDR4 (Tipe: DDR4).
# Total RAM sekarang: 20 GB
#
# Uggrade RAM dengan nilai eksplisit untuk tipe_ram
# RAM Dell XPS diupgrade menjadi 40 GB DDR5 (Tipe: DDR5).
# Total RAM sekarang: 40 GB
#
# Demonstrasi Overloading dengan ARGS:
# Menginstall satu software:
# Menginstall Adobe Photoshop di Asus
#
# Menginstall beberapa software:
# Menginstall Microsoft Office di Dell XPS
# Menginstall Google Drive di Dell XPS

# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadchoms/2025_PBO_TI_1A/blob/main/Jobsheet_PBO_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Praktikum 01. Tipe data dasar\n")

print("Integer (int)")
angka_int = 10
print(f"angka_int = {angka_int} => {type(angka_int)}  # Bilangan bulat")

print("\nFloat (float)")
angka_float = 3.14
print(f"angka_float = {angka_float} => {type(angka_float)}  # Bilangan desimal")

print("\nComplex (complex)")
angka_complex = 2 + 3j
print(f"angka_complex = {angka_complex} => {type(angka_complex)}  # Bilangan kompleks")

print("\nBoolean (bool)")
is_active = True
print(f"is_active = {is_active} => {type(is_active)}  # Nilai True atau False")

print("\nString (str)")
teks = "Hello, Python"
print(f"teks = {teks} => {type(teks)}  # Teks atau kumpulan karakter")

print("\nList (list)")
daftar_angka = [1, 2, 3, 4, 5]
print(f"daftar_angka = {daftar_angka} => {type(daftar_angka)}  # Koleksi yang bisa diubah (mutable)")

print("\nTuple (tuple)")
koordinat = (10, 20)
print(f"koordinat = {koordinat} => {type(koordinat)}  # Koleksi yang tidak bisa diubah (immutable)")

print("\nDictionary (dict)")
data_mahasiswa = {
    "nama": "Andi",
    "nim": "4.33.24.0.01",
    "jurusan": "Teknik Informatika"
}
print(f"data_mahasiswa = {data_mahasiswa} => {type(data_mahasiswa)}  # Struktur data dengan key-value")

print("\nSet (set)")
himpunan_angka = {1, 2, 3, 4}
print(f"himpunan_angka = {himpunan_angka} => {type(himpunan_angka)}  # Koleksi unik tanpa duplikasi")

print("\nKonversi String ke Integer")
nilai_str = "100"
print(f"nilai_str = {nilai_str} => {type(nilai_str)}  # Teks yang merepresentasikan angka")
nilai_int = int(nilai_str)
print(f"nilai_int = {nilai_int} => {type(nilai_int)}  # Konversi string ke integer")
# Out:
# Praktikum 01. Tipe data dasar
#
# Integer (int)
# angka_int = 10 => <class 'int'>  # Bilangan bulat
#
# Float (float)
# angka_float = 3.14 => <class 'float'>  # Bilangan desimal
#
# Complex (complex)
# angka_complex = (2+3j) => <class 'complex'>  # Bilangan kompleks
#
# Boolean (bool)
# is_active = True => <class 'bool'>  # Nilai True atau False
#
# String (str)
# teks = Hello, Python => <class 'str'>  # Teks atau kumpulan karakter
#
# List (list)
# daftar_angka = [1, 2, 3, 4, 5] => <class 'list'>  # Koleksi yang bisa diubah (mutable)
#
# Tuple (tuple)
# koordinat = (10, 20) => <class 'tuple'>  # Koleksi yang tidak bisa diubah (immutable)
#
# Dictionary (dict)
# data_mahasiswa = {'nama': 'Andi', 'nim': '4.33.24.0.01', 'jurusan': 'Teknik Informatika'} => <class 'dict'>  # Struktur data dengan key-value
#
# Set (set)
# himpunan_angka = {1, 2, 3, 4} => <class 'set'>  # Koleksi unik tanpa duplikasi
#
# Konversi String ke Integer
# nilai_str = 100 => <class 'str'>  # Teks yang merepresentasikan angka
# nilai_int = 100 => <class 'int'>  # Konversi string ke integer

# %%
print("Praktikum 02. Variabel dan Operasi Dasar\n")

print("Pendeklarasian Variabel tidak perlu diberi keterangan secara detail atau eksplisit")

# 1. Deklarasi Variabel
nama = "Budi"       # String
umur = 20           # Integer
tinggi = 170.5      # Float
is_student = True   # Boolean

# Menampilkan nilai variabel
print("\n===== VARIABEL =====")
print(f"Nama = {nama}, Umur = {umur}, Tinggi = {tinggi}, Mahasiswa = {is_student}  # Menampilkan variabel yang telah dideklarasikan")

# 2. Operasi Aritmatika
a = 10
b = 3

penjumlahan = a + b
pengurangan = a - b
perkalian = a * b
pembagian = a / b
modulus = a // b
pangkat = a ** b

print("\n===== OPERASI ARITMATIKA =====")
print(f"{a} + {b} = {penjumlahan}  # Operasi penjumlahan")
print(f"{a} - {b} = {pengurangan}  # Operasi pengurangan")
print(f"{a} * {b} = {perkalian}  # Operasi perkalian")
print(f"{a} / {b} = {pembagian}  # Operasi pembagian (hasil float)")
print(f"{a} // {b} = {modulus}  # Operasi modulus (hasil pembagian bulat)")
print(f"{a} ** {b} = {pangkat}  # Operasi perpangkatan")

# 3. Operasi Perbandingan
# Menghasilkan nilai Boolean (True/False)
lebih_besar = a > b
kurang_dari = a < b
sama_dengan = a == b
tidak_sama = a != b
lebih_besar_sama = a >= b
kurang_sama = a <= b

print("\n===== OPERASI PERBANDINGAN =====")
print(f"{a} > {b}  = {lebih_besar}  # Apakah a lebih besar dari b?")
print(f"{a} < {b}  = {kurang_dari}  # Apakah a lebih kecil dari b?")
print(f"{a} == {b} = {sama_dengan}  # Apakah a sama dengan b?")
print(f"{a} != {b} = {tidak_sama}  # Apakah a tidak sama dengan b?")
print(f"{a} >= {b} = {lebih_besar_sama}  # Apakah a lebih besar atau sama dengan b?")
print(f"{a} <= {b} = {kurang_sama}  # Apakah a lebih kecil atau sama dengan b?")

# 4. Operasi Logika
# Menggunakan operator logika: and, or, not
x = True
y = False

logika_and = x and y
logika_or = x or y
logika_not_x = not x

print("\n===== OPERASI LOGIKA =====")
print(f"x = {x}, y = {y}  # Menampilkan nilai boolean x dan y")
print(f"x and y = {logika_and}  # True jika keduanya True")
print(f"x or y  = {logika_or}  # True jika salah satu True")
print(f"not x   = {logika_not_x}  # Kebalikan dari nilai x")

# 5. Percabangan (if-else)
print("\n===== PERCABANGAN =====")
print("Mengecek apakah a lebih besar dari b dan b lebih besar dari 0...")
if a > b and b > 0:
    print("Kondisi terpenuhi: a lebih besar dari b, dan b masih positif.")
else:
    print("Kondisi tidak terpenuhi atau b <= 0.")
# Out:
# Praktikum 02. Variabel dan Operasi Dasar
#
# Pendeklarasian Variabel tidak perlu diberi keterangan secara detail atau eksplisit
#
# ===== VARIABEL =====
# Nama = Budi, Umur = 20, Tinggi = 170.5, Mahasiswa = True  # Menampilkan variabel yang telah dideklarasikan
#
# ===== OPERASI ARITMATIKA =====
# 10 + 3 = 13  # Operasi penjumlahan
# 10 - 3 = 7  # Operasi pengurangan
# 10 * 3 = 30  # Operasi perkalian
# 10 / 3 = 3.3333333333333335  # Operasi pembagian (hasil float)
# 10 // 3 = 3  # Operasi modulus (hasil pembagian bulat)
# 10 ** 3 = 1000  # Operasi perpangkatan
#
# ===== OPERASI PERBANDINGAN =====
# 10 > 3  = True  # Apakah a lebih besar dari b?
# 10 < 3  = False  # Apakah a lebih kecil dari b?
# 10 == 3 = False  # Apakah a sama dengan b?
# 10 != 3 = True  # Apakah a tidak sama dengan b?
# 10 >= 3 = True  # Apakah a lebih besar atau sama dengan b?
# 10 <= 3 = False  # Apakah a lebih kecil atau sama dengan b?
#
# ===== OPERASI LOGIKA =====
# x = True, y = False  # Menampilkan nilai boolean x dan y
# x and y = False  # True jika keduanya True
# x or y  = True  # True jika salah satu True
# not x   = False  # Kebalikan dari nilai x
#
# ===== PERCABANGAN =====
# Mengecek apakah a lebih besar dari b dan b lebih besar dari 0...
# Kondisi terpenuhi: a lebih besar dari b, dan b masih positif.

# %%
print("Praktikum 03. Percabangan")

# 1. IF Sederhana
# Program hanya mengeksekusi blok jika kondisinya True

nilai = 85
print("\n===== Contoh IF Sederhana =====")
print(f"Nilai Anda: {nilai}")
if nilai > 80:
    print("Selamat! Anda lulus dengan nilai tinggi. Karena nilai lebih dari 80\n")  # Pesan hanya ditampilkan jika nilai lebih dari 80


# 2. IF-ELSE
# Jika kondisi True, eksekusi blok if; jika False, eksekusi blok else

umur = 17
print("\n===== Contoh IF-ELSE =====")
print(f"Umur Anda: {umur}")
if umur >= 18:
    print("Anda sudah cukup umur untuk mendapatkan SIM. Karena umur lebih besar sama dengan 18")  # Jika umur >= 18
else:
    print("Anda belum cukup umur untuk mendapatkan SIM. Karena umur kurang dari 18\n")  # Jika umur < 18


# 3. IF-ELIF-ELSE
# Menangani banyak kondisi secara berurutan.

hari = "Rabu"
print("\n===== Contoh IF-ELIF-ELSE =====")
print(f"Hari ini adalah: {hari}")
if hari == "Senin":
    print("Hari Senin - Saatnya kembali bekerja. Jika hari bernilai Senin")  # Jika hari Senin
elif hari == "Selasa":
    print("Hari Selasa - Jadwal rapat mingguan. Jika hari bernilai Selasa")  # Jika hari Selasa
elif hari == "Rabu":
    print("Hari Rabu - Ada diskon di beberapa toko. Jika hari bernilai Rabu")  # Jika hari Rabu
else:
    print("Hari lainnya - Atur jadwalmu dengan baik. Jika hari bernilai selain dari kondisi diatas\n")  # Untuk semua hari lainnya


# 4. IF Bersarang (Nested IF)
# Kondisi di dalam kondisi untuk memeriksa sub-kondisi setelah kondisi pertama terpenuhi.

suhu = 35
print("\n===== Contoh IF Bersarang (Nested IF) =====")
print(f"Suhu saat ini: {suhu}°C")
if suhu > 30:
    print("Cuaca cukup panas. Jika suhu lebih dari 30")  # Jika suhu lebih dari 30°C
    if suhu > 40:
        print("Bahkan sangat terik! Disarankan banyak minum air. Jika suhu lebih dari 40")  # Jika suhu lebih dari 40°C
    else:
        print("Masih relatif normal, tapi tetap jaga kesehatan. Jika tidak lebih dari 40, tetapi lebih dari 30")  # Jika suhu antara 30°C dan 40°C
else:
    print("Cuaca sepertinya cukup sejuk. Jika suhu kurang dari 30\n")  # Jika suhu 30°C atau kurang


# 5. Menggabungkan Percabangan dengan Operasi Logika
# Memeriksa beberapa kondisi sekaligus dengan and, or, not

nilai_teori = 75
nilai_praktik = 80
print("\n===== Contoh IF dengan Operasi Logika AND/OR =====")
print(f"Nilai Teori: {nilai_teori}, Nilai Praktik: {nilai_praktik}")
if nilai_teori >= 70 and nilai_praktik >= 70:
    print("Anda lulus karena nilai teori dan praktik memadai. Jika nilai_teori dan nilai_praktik lebih dari sama dengan 70")  # Lulus jika kedua nilai >= 70
elif nilai_teori < 70 and nilai_praktik < 70:
    print("Anda perlu meningkatkan nilai teori dan praktik. Jika nilai_teori dan nilai_praktik kurang dari 70")  # Jika kedua nilai di bawah 70
elif nilai_teori < 70:
    print("Anda perlu meningkatkan nilai teori. Jika nilai_teori kurang dari 70")  # Jika hanya nilai teori yang kurang
else:
    print("Anda perlu meningkatkan nilai praktik. Jika nilai_praktik kurang dari 70\n")  # Jika hanya nilai praktik yang kurang


# 6. Penggunaan If Ternary (atau Conditional Expression)
# Bentuk ringkas: <hasil_if_true> if <kondisi> else <hasil_if_false>

angka = -5
print("\n===== Contoh IF Ternary (Conditional Expression) =====")
status = "Positif" if angka > 0 else "Negatif atau Nol"
print(f"Angka = {angka} => {status}")  # Menampilkan hasil positif atau negatif berdasarkan kondisi angka
# Out:
# Praktikum 03. Percabangan
#
# ===== Contoh IF Sederhana =====
# Nilai Anda: 85
# Selamat! Anda lulus dengan nilai tinggi. Karena nilai lebih dari 80
#
#
# ===== Contoh IF-ELSE =====
# Umur Anda: 17
# Anda belum cukup umur untuk mendapatkan SIM. Karena umur kurang dari 18
#
#
# ===== Contoh IF-ELIF-ELSE =====
# Hari ini adalah: Rabu
# Hari Rabu - Ada diskon di beberapa toko. Jika hari bernilai Rabu
#
# ===== Contoh IF Bersarang (Nested IF) =====
# Suhu saat ini: 35°C
# Cuaca cukup panas. Jika suhu lebih dari 30
# Masih relatif normal, tapi tetap jaga kesehatan. Jika tidak lebih dari 40, tetapi lebih dari 30
#
# ===== Contoh IF dengan Operasi Logika AND/OR =====
# Nilai Teori: 75, Nilai Praktik: 80
# Anda lulus karena nilai teori dan praktik memadai. Jika nilai_teori dan nilai_praktik lebih dari sama dengan 70
#
# ===== Contoh IF Ternary (Conditional Expression) =====
# Angka = -5 => Negatif atau Nol

# %%
print("Praktikum 04. Perulangan")

# 1. FOR Loop dengan range()
print("\n===== 1) FOR loop dengan range() =====")
print("Perulangan menggunakan range(5), yang berarti akan mengulang dari 0 hingga 4.")
for i in range(5):
    print("Perulangan ke-", i)
# range(5) menghasilkan nilai 0, 1, 2, 3, dan 4

print()  # Pemisah output


# 2. FOR Loop untuk mengiterasi List
print("===== 2) FOR loop mengiterasi list =====")
buah = ["apel", "mangga", "jeruk", "pisang"]
print("Loop ini akan menampilkan setiap elemen dalam list 'buah'.")
for item in buah:
    print("Buah:", item)
# Loop akan mengeksekusi setiap elemen dalam list "buah"

print()


# 3. WHILE Loop
print("===== 3) WHILE loop sederhana =====")
count = 0
print("Perulangan akan terus berjalan selama count kurang dari 5.")
while count < 5:
    print("count =", count)
    count += 1  # Increment
# Perulangan while terus dijalankan selama kondisi (count < 5) bernilai True

print()


# 4. BREAK pada Loop
print("===== 4) BREAK di dalam loop =====")
print("Loop ini akan berhenti saat i = 3 karena ada break.")
for i in range(10):
    if i == 3:
        print("Loop dihentikan pada i =", i)
        break  # Mengakhiri loop saat i = 3
    print("i =", i)
# Keyword break langsung menghentikan keseluruhan perulangan

print()


# 5. CONTINUE pada Loop
print("===== 5) CONTINUE di dalam loop =====")
print("Saat i = 2, iterasi akan dilewati dan lanjut ke angka berikutnya.")
for i in range(5):
    if i == 2:
        print("Lewati i =", i, "dengan continue")
        continue  # Melewati iterasi saat ini dan lanjut ke iterasi berikutnya
    print("i =", i)
# Saat i = 2, baris print("i =", i) tidak akan dieksekusi

print()


# 6. NESTED Loop (Loop Bersarang)
print("===== 6) NESTED loop =====")
print("Loop dalam akan berjalan lebih cepat dibanding loop luar.")
for i in range(3):  # Loop luar (outer loop)
    for j in range(2):  # Loop dalam (inner loop)
        print(f"i={i}, j={j}")
# Pada setiap iterasi i, loop j akan berjalan dari 0 sampai 1

print()


# 7. Memanfaatkan ELSE pada Loop
print("===== 7) ELSE pada loop for/while =====")
print("Jika loop berjalan sampai selesai tanpa break, blok else akan dieksekusi.")

for x in range(3):
    print("x =", x)
else:
    print("Loop for telah selesai tanpa break.\n")

y = 0
while y < 3:
    print("y =", y)
    y += 1
else:
    print("Loop while telah selesai tanpa break.\n")


# 8. PASS sebagai placeholder
print("===== 8) PASS (placeholder) =====")
print("PASS digunakan sebagai placeholder ketika blok kode belum diimplementasikan.")
for i in range(3):
    if i == 1:
        pass  # pass tidak melakukan apa-apa, digunakan sebagai placeholder
    print("i =", i)
# Out:
# Praktikum 04. Perulangan
#
# ===== 1) FOR loop dengan range() =====
# Perulangan menggunakan range(5), yang berarti akan mengulang dari 0 hingga 4.
# Perulangan ke- 0
# Perulangan ke- 1
# Perulangan ke- 2
# Perulangan ke- 3
# Perulangan ke- 4
#
# ===== 2) FOR loop mengiterasi list =====
# Loop ini akan menampilkan setiap elemen dalam list 'buah'.
# Buah: apel
# Buah: mangga
# Buah: jeruk
# Buah: pisang
#
# ===== 3) WHILE loop sederhana =====
# Perulangan akan terus berjalan selama count kurang dari 5.
# count = 0
# count = 1
# count = 2
# count = 3
# count = 4
#
# ===== 4) BREAK di dalam loop =====
# Loop ini akan berhenti saat i = 3 karena ada break.
# i = 0
# i = 1
# i = 2
# Loop dihentikan pada i = 3
#
# ===== 5) CONTINUE di dalam loop =====
# Saat i = 2, iterasi akan dilewati dan lanjut ke angka berikutnya.
# i = 0
# i = 1
# Lewati i = 2 dengan continue
# i = 3
# i = 4
#
# ===== 6) NESTED loop =====
# Loop dalam akan berjalan lebih cepat dibanding loop luar.
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1
#
# ===== 7) ELSE pada loop for/while =====
# Jika loop berjalan sampai selesai tanpa break, blok else akan dieksekusi.
# x = 0
# x = 1
# x = 2
# Loop for telah selesai tanpa break.
#
# y = 0
# y = 1
# y = 2
# Loop while telah selesai tanpa break.
#
# ===== 8) PASS (placeholder) =====
# PASS digunakan sebagai placeholder ketika blok kode belum diimplementasikan.
# i = 0
# i = 1
# i = 2

# %%
def calculate_bmi(weight, height_cm):
    height_m = height_cm / 100
    if height_m <= 0:
        raise ValueError("Tinggi harus lebih besar dari 0.")
    return weight / (height_m ** 2)


def bmi_program():
    try:
        weight = float(input("Masukan berat (kg): "))
        height_cm = float(input("Masukan tinggi (cm): "))
        bmi = calculate_bmi(weight, height_cm)
        print(f"Nilai berat: {weight} kg, tinggi: {height_cm} cm")
        print(f"Nilai BMI mu: {bmi:.2f}")

        if bmi < 18.5:
            print("Kategori BMI: Underweight")
        elif 18.5 <= bmi < 24.9:
            print("Kategori BMI: Normal weight")
        elif 25 <= bmi < 29.9:
            print("Kategori BMI: Overweight")
        else:
            print("Kategori BMI: Obesity")
    except ValueError as e:
        print(f"Input invalid: {e}")


if __name__ == "__main__":
    bmi_program()
# Out:
# Masukan berat (kg): 200
# Masukan tinggi (cm): 200
# Nilai berat: 200.0 kg, tinggi: 200.0 cm
# Nilai BMI mu: 50.00
# Kategori BMI: Obesity

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True


def check_number():
    try:
        num = int(input("Masukan angka: "))
        if num % 2 == 0:
            print(f"{num} adalah angka genap.")
        else:
            print(f"{num} adalah angka ganjil.")
        if is_prime(num):
            print(f"{num} adalah angka Prima.")
        else:
            print(f"{num} bukan angka Prima.")
    except ValueError:
        print("Input harus berupa angka.")


if __name__ == "__main__":
    check_number()
# Out:
# Masukan angka: 234236462368
# 234236462368 adalah angka genap.
# 234236462368 bukan angka Prima.
